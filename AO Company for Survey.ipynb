# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Strategy & Intelligence  - Copy of Apply Online Related (4).csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16511 entries, 0 to 16510
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Company Name            16511 non-null  object
#  1   AO                      16511 non-null  int64
#  2   AOP                     16511 non-null  int64
#  3   NAO                     16511 non-null  int64
#  4   Total                   16511 non-null  int64
#  5   Companys Industry Type  16511 non-null  object
#  6   Phone Number            15731 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 903.1+ KB

# %%
df.dropna(inplace=True)

# %%
df=df[(df['AO']!=0) | (df['AOP']!=0) | (df['NAO']!=0)]

# %%
df['Total'].hist(bins=20)
# Out:
# <Axes: >

# %%
df[df['Total']>200]
# Out:
#                                      Company Name    AO  AOP  NAO  Total  \
# 40                                           BRAC   193  274  441    927
# 43                                 Epyllion Group   164  325    0    489
# 79                     Palmal Group of Industries   504  348   35    887
# 201            A Reputed Garments & Textile Group   292    8    0    300
# 238    Advanced Chemical Industries Limited (ACI)  1022    6    0   1028
# 270                                     DBL GROUP   448   19    7    475
# 326                             Bashundhara Group   539  229    7    775
# 328                                    Banglalink     0    2  206    208
# 368                                        Aarong    12  205    0    217
# 395                              Deshbandhu Group   286   36    0    322
# 433                   Interstoff Apparels Limited   223    0    0    223
# 471                                     BJIT Ltd.     9  197   27    233
# ...

# %%
sns.boxplot(df['AOP'])
# Out:
# <Axes: >

# %%
df['Industry']=df['Companys Industry Type'].str.split(',').str[0]

# %%
df.drop('Companys Industry Type',axis=1,inplace=True)

# %%
big=df[df['Total']>150]
medium=df[(df['Total']<=150) & (df['Total']>30)]
small=df[df['Total']<=30]

# %%
len(big)
# Out:
# 92

# %%
medium.describe()
# Out:
#                AO         AOP         NAO       Total
# count  775.000000  775.000000  775.000000  775.000000
# mean    33.171613   13.672258   13.992258   60.841290
# std     32.021072   21.444561   26.258749   27.798636
# min      0.000000    0.000000    0.000000   31.000000
# 25%      1.000000    0.000000    0.000000   39.000000
# 50%     31.000000    3.000000    0.000000   51.000000
# 75%     51.000000   20.000000   16.000000   76.000000
# max    143.000000  130.000000  136.000000  149.000000

# %%
df
# Out:
#                                 Company Name   AO  AOP  NAO  Total  \
# 0                             STANDARD GROUP    8   70    0     78
# 1                                  DNS Group    5    0    0      5
# 2                        Eastern University,    0    0    1      1
# 6                              FCI (BD) Ltd.  121    2    0    123
# 17     New Horizons Computer Learning Center    0    3    2      5
# ...                                      ...  ...  ...  ...    ...
# 16506           Prochesta Healthcare Limited    1    0    0      1
# 16507                    MINE SOLUTIONS LTD.    1    0    0      1
# 16508                      Chomok Restaurant    0    0    2      2
# 16509                            Tech Inside    0    1    0      1
# 16510                          Red Lifestyle    2    0    0      2
#
#                                           Phone Number  \
# 0                                         Dhaka, Dhaka
# ...

# %%
big
# Out:
#                      Company Name   AO  AOP  NAO  Total  \
# 40                           BRAC  193  274  441    927
# 43                 Epyllion Group  164  325    0    489
# 70                Ad-din Hospital    1    0  193    194
# 79     Palmal Group of Industries  504  348   35    887
# 108                      SQ Group  197    2    0    199
# ...                           ...  ...  ...  ...    ...
# 6028                       ShopUp  166   18    8    192
# 7009        Liberty Knitwear Ltd.  159    0    0    159
# 11997                       BRAC.  701    5   20    726
# 15310                  Akij Group  957   97   45   1099
# 15634           Confidence Group.  352    1    1    354
#
#                                             Phone Number  \
# 40                              01708498694, 01708812669
# 43           88-02 9006028,9006747,8013883 & 01730051801
# 70                                            1674614474
# 79                                      88-02-55048321-5
# ...

# %%
df['Industry'].value_counts()
# Out:
# Others                                                       2077
# Information Technology (IT)                                  1618
# Garments/ Textile                                            1394
# Wholesale/ Retail/ Export-Import                             1192
# Education                                                    1125
# Manufacturing (Heavy Industry)                                810
# NGO/Development                                               788
# Architecture/ Engineering/ Construction                       763
# Real Estate/ Development                                      587
# Hospital/ Diagnostic Center                                   503
# Hotel/Restaurant                                              423
# E-commerce/F-commerce                                         412
# Agro based Industry                                           410
# Pharmaceuticals                                               395
# ...

# %%
from sklearn.model_selection import train_test_split

# Splitting the dataframe into features and target
X = df
y = df['Industry']

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y)

# %%
X_test['Industry'].value_counts()
# Out:
# Others                                                       623
# Information Technology (IT)                                  485
# Garments/ Textile                                            418
# Wholesale/ Retail/ Export-Import                             358
# Education                                                    338
# Manufacturing (Heavy Industry)                               243
# NGO/Development                                              236
# Architecture/ Engineering/ Construction                      229
# Real Estate/ Development                                     176
# Hospital/ Diagnostic Center                                  151
# Hotel/Restaurant                                             127
# E-commerce/F-commerce                                        124
# Agro based Industry                                          123
# Pharmaceuticals                                              119
# ...

# %%
big_f=X_test[X_test['Total']>50]
big_f.to_csv('Big Companies.csv')

# %%
medium_f=X_test[(X_test['Total']<=50) & (X_test['Total']>10)]
medium_f.to_csv('Medium Companies.csv')
small_f=X_test[X_test['Total']<=10]
small_f.to_csv('Small Companies.csv')

# %%
small_f
# Out:
#                            Company Name  AO  AOP  NAO  Total  \
# 10173  Next Food and Beverage Ind. Ltd.   2    1    0      3
# 15284                             GIFZI   0    2    0      2
# 8770         We Fashion Group Companies   0    2    1      3
# 7930           Grocerant.com.bd Limited   0    0    1      1
# 14209                         Son Kutir   0    1    3      4
# ...                                 ...  ..  ...  ...    ...
# 1061              Excellent Corporation   2    0    1      3
# 12286                Zass Impex Limited   2    0    2      4
# 2627          High Commission of Canada   0    0    7      7
# 6418   Huaxia International Trading Co.   0    1    0      1
# 2301              Caritas Sylhet Region   0    0    8      8
#
#                                             Phone Number  \
# 10173                           01748993622, 01938886313
# 15284                                         1670445665
# 8770                                          1777767425
# ...

# %%
medium_f['Industry'].value_counts()
# Out:
# Information Technology (IT)                                  68
# Garments/ Textile                                            65
# Others                                                       65
# NGO/Development                                              57
# Manufacturing (Heavy Industry)                               34
# Education                                                    33
# Architecture/ Engineering/ Construction                      28
# Wholesale/ Retail/ Export-Import                             28
# Bank/ Non-Bank Fin. Institution                              23
# Real Estate/ Development                                     22
# Hospital/ Diagnostic Center                                  19
# E-commerce/F-commerce                                        19
# Pharmaceuticals                                              16
# Agro based Industry                                          16
# Hotel/Restaurant                                             14
# ...

# %%
small_d=small_f[small_f['Total']>5]
small_d.to_csv('Small Companies New.csv')
